# %%
import numpy as np
from lazy_opt import LazyOpt

hyper_params = {'surrogate':'KNN',
                'epsilon':1,
                'number_of_DOE_samples':30,
                'number_of_iterations':10,
                'number_of_psuedo_candidates':1000
}
options = {'live_plot_draw':True,
           'latent_plot_draw':False,
           'number_of_processes':1,
           'save_csv_filename':'save_csv.csv',
           'save_csv_boolean':True
}
bounds = {
    'x1':(-3,3),
    'x2':(-3,3)
}
def function_call(input_row):
    # === CONFIGURATION ===

    x1 = input_row[0, 0]
    x2 = input_row[0, 1]

    f1 = (3 * (1 - x1) ** 2 * np.exp(-(x1 ** 2) - (x2 + 1) ** 2)
          - 10 * (x1 / 5 - x1 ** 3 - x2 ** 5) * np.exp(-x1 ** 2 - x2 ** 2)
          - 1 / 3 * np.exp(-(x1 + 1) ** 2 - x2 ** 2))

    feasible = f1 < 2

    # % quantization constriant (anything !!greater!! than 2 is good-stable)
    # f_star = z_values < 2; % since 0 is good, take the inverse of the constarint ie <
    return feasible, (f1,)

# %%
lazy = LazyOpt(solver_function=function_call,
               bounds=bounds,
               hyper_params=hyper_params,
               seed=None,
               options=options
               )
print('='*50)
print('lazy opt finished')
print('='*50)
# Out:
# Bounds set for 2 dimensions: ['x1', 'x2']
# No seed provided, will rely on DoE sampling only
#
# === function_call ===
# f1     :       0.05
# feasible      :       [ ]
# sampling 1/30
#
# === function_call ===
# f1     :       0.28
# feasible      :       [ ]
# sampling 2/30
#
# === function_call ===
# f1     :       0.34
# feasible      :       [ ]
# sampling 3/30
#
# === function_call ===
# f1     :       2.54
# feasible      :       [X]
# sampling 4/30
#
# === function_call ===
# f1     :       0.80
# feasible      :       [ ]
# sampling 5/30
#
# === function_call ===
# f1     :       0.00
# feasible      :       [ ]
# sampling 6/30
#
# === function_call ===
# f1     :       -0.77
# feasible      :       [ ]
# sampling 7/30
#
# === function_call ===
# f1     :       -0.02
# feasible      :       [ ]
# sampling 8/30
#
# === function_call ===
# f1     :       0.01
# feasible      :       [ ]
# sampling 9/30
#
# === function_call ===
# f1     :       -0.01
# feasible      :       [ ]
# sampling 10/30
#
# === function_call ===
# f1     :       -1.88
# feasible      :       [ ]
# sampling 11/30
#
# === function_call ===
# f1     :       1.94
# feasible      :       [ ]
# sampling 12/30
#
# === function_call ===
# f1     :       0.51
# feasible      :       [ ]
# sampling 13/30
#
# === function_call ===
# f1     :       -0.36
# feasible      :       [ ]
# sampling 14/30
#
# === function_call ===
# f1     :       -3.37
# feasible      :       [ ]
# sampling 15/30
#
# === function_call ===
# f1     :       0.03
# feasible      :       [ ]
# sampling 16/30
#
# === function_call ===
# f1     :       -1.89
# feasible      :       [ ]
# sampling 17/30
#
# === function_call ===
# f1     :       0.12
# feasible      :       [ ]
# sampling 18/30
#
# === function_call ===
# f1     :       3.77
# feasible      :       [X]
# sampling 19/30
#
# === function_call ===
# f1     :       -0.32
# feasible      :       [ ]
# sampling 20/30
#
# === function_call ===
# f1     :       -0.01
# feasible      :       [ ]
# sampling 21/30
#
# === function_call ===
# f1     :       -0.00
# feasible      :       [ ]
# sampling 22/30
#
# === function_call ===
# f1     :       2.54
# feasible      :       [X]
# sampling 23/30
#
# === function_call ===
# f1     :       -0.00
# feasible      :       [ ]
# sampling 24/30
#
# === function_call ===
# f1     :       0.47
# feasible      :       [ ]
# sampling 25/30
#
# === function_call ===
# f1     :       -0.23
# feasible      :       [ ]
# sampling 26/30
#
# === function_call ===
# f1     :       0.59
# feasible      :       [ ]
# sampling 27/30
#
# === function_call ===
# f1     :       -1.47
# feasible      :       [ ]
# sampling 28/30
#
# === function_call ===
# f1     :       2.99
# feasible      :       [X]
# sampling 29/30
#
# === function_call ===
# f1     :       -0.09
# feasible      :       [ ]
# sampling 30/30
#
# Number of Hits from Sampling Found: 26
#
# === function_call ===
# f1     :       3.67
# feasible      :       [X]
# infill function call: iter 0
# time for iter: 0.015543460845947266s
#
# FAST latent embedding took: 1.5335984230041504s
# For a more structured plot please use TSNE on x__1=PCA(x_xxx_) with Mahalanobis distance
# latent plot generated
# Appended 1 samples to save_csv.csv
#
# === function_call ===
# f1     :       3.43
# feasible      :       [X]
# infill function call: iter 1
# time for iter: 4.222199201583862s
#
# FAST latent embedding took: 0.1700291633605957s
# For a more structured plot please use TSNE on x__1=PCA(x_xxx_) with Mahalanobis distance
# latent plot generated
# Appended 1 samples to save_csv.csv
#
# === function_call ===
# f1     :       1.41
# feasible      :       [ ]
# infill function call: iter 2
# time for iter: 7.421985626220703s
#
# FAST latent embedding took: 0.10625553131103516s
# For a more structured plot please use TSNE on x__1=PCA(x_xxx_) with Mahalanobis distance
# latent plot generated
# Appended 1 samples to save_csv.csv
#
# === function_call ===
# f1     :       3.69
# feasible      :       [X]
# infill function call: iter 3
# time for iter: 10.054110050201416s
#
# FAST latent embedding took: 0.1000661849975586s
# For a more structured plot please use TSNE on x__1=PCA(x_xxx_) with Mahalanobis distance
# latent plot generated
# Appended 1 samples to save_csv.csv
#
# === function_call ===
# f1     :       5.05
# feasible      :       [X]
# infill function call: iter 4
# time for iter: 12.973578691482544s
#
# FAST latent embedding took: 0.2847161293029785s
# For a more structured plot please use TSNE on x__1=PCA(x_xxx_) with Mahalanobis distance
# latent plot generated
# Appended 1 samples to save_csv.csv
#
# === function_call ===
# f1     :       0.23
# feasible      :       [ ]
# infill function call: iter 5
# time for iter: 15.962762117385864s
#
# FAST latent embedding took: 0.13158059120178223s
# For a more structured plot please use TSNE on x__1=PCA(x_xxx_) with Mahalanobis distance
# latent plot generated
# Appended 1 samples to save_csv.csv
#
# === function_call ===
# f1     :       3.80
# feasible      :       [X]
# infill function call: iter 6
# time for iter: 19.229995012283325s
#
# FAST latent embedding took: 0.12333059310913086s
# For a more structured plot please use TSNE on x__1=PCA(x_xxx_) with Mahalanobis distance
# latent plot generated
# Appended 1 samples to save_csv.csv
#
# === function_call ===
# f1     :       2.21
# feasible      :       [X]
# infill function call: iter 7
# time for iter: 21.88802433013916s
#
# FAST latent embedding took: 0.08434200286865234s
# For a more structured plot please use TSNE on x__1=PCA(x_xxx_) with Mahalanobis distance
# latent plot generated
# Appended 1 samples to save_csv.csv
#
# === function_call ===
# f1     :       4.26
# feasible      :       [X]
# infill function call: iter 8
# time for iter: 24.460725784301758s
#
# FAST latent embedding took: 0.10036611557006836s
# For a more structured plot please use TSNE on x__1=PCA(x_xxx_) with Mahalanobis distance
# latent plot generated
# Appended 1 samples to save_csv.csv
#
# === function_call ===
# f1     :       6.05
# feasible      :       [X]
# infill function call: iter 9
# time for iter: 27.47299027442932s
#
# FAST latent embedding took: 0.3443005084991455s
# For a more structured plot please use TSNE on x__1=PCA(x_xxx_) with Mahalanobis distance
# latent plot generated
# Appended 1 samples to save_csv.csv
#
# === function_call ===
# f1     :       3.86
# feasible      :       [X]
# infill function call: iter 10
# ==================================================
# lazy opt finished
# ==================================================

# %%
# Run this app with `python app.py` and
# visit http://127.0.0.1:8050/ in your web browser.


from dash import Dash, dcc, html
import plotly.graph_objects as go

app = Dash()

colors = {
    'background': '#FFFFFF',
    'text': '#111111'
}

# Create figure and add both traces
fig = go.Figure()

fig.add_trace(go.Scattergl(
    x=lazy.xxx[:,0],
    y=lazy.xxx[:,1],
    mode='markers',
    name='xxx',
    marker=dict(size=8)
))

fig.add_trace(go.Scattergl(
    x=lazy.x[:,0],
    y=lazy.x[:,1],
    mode='markers',
    name='x',
    marker=dict(size=8)
))

fig.update_layout(
    plot_bgcolor=colors['background'],
    paper_bgcolor=colors['background'],
    font_color=colors['text'],
    height=700,
    xaxis_title='x1',
    yaxis_title='x2',
    yaxis=dict(scaleanchor="x", scaleratio=1)
)

app.layout = html.Div(style={'backgroundColor': colors['background']}, children=[
    html.H1(
        children='Hello Dash',
        style={
            'textAlign': 'center',
            'color': colors['text']
        }
    ),

    html.Div(children='Dash: A web application framework for your data.', style={
        'textAlign': 'center',
        'color': colors['text']
    }),

    html.Div(style={'display': 'flex', 'flexDirection': 'row'}, children=[
        html.Div(style={'width': '70%'}, children=[
            dcc.Graph(
                id='example-graph-2',
                figure=fig
            )
        ]),

        html.Div(style={'width': '30%'}, children=[
            html.Iframe(
                src='/assets/optimization_tour.html',
                style={"height":"700px","width":"100%"}
            )
        ])
    ])
])

if __name__ == '__main__':
    app.run(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
